# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv("/content/data.csv",encoding='latin1')

df
state='Tamilnadu'
location='Thoothukudi'
p1=sns.lineplot(x='state',y='location',data=df)

sns.relplot(data=df,x="state",y="location",hue="type",style="stn_code")
# Out:
# <ipython-input-17-391204370687>:3: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/data.csv",encoding='latin1')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-391204370687> in <cell line: 10>()
#       8 p1=sns.lineplot(x='state',y='location',data=df)
#       9
# ---> 10 sns.relplot(data=df,x="state",y="location",hue="type",style="stn_code")
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in relplot(data, x, y, hue, size, style, units, weights, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#     869         p.add_legend_data(g.axes.flat[0], legend_artist, common_kws, attrs)
#     870         if p.legend_data:
# ...

# %%
import pandas as pd
import seaborn as sns
df=pd.read_csv("/content/data.csv", encoding='latin1')
data = df[df['state']=='Tamilnadu']
sns.relplot(data=data,x='location',y='no2',hue='location')
# Out:
# <ipython-input-14-d265daa91b3e>:3: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("/content/data.csv", encoding='latin1')

# %%
import pandas as pd
import seaborn as sns


df=pd.read_csv("/content/data.csv", encoding='latin1')
df

state='Tamilnadu'
location='Thoothukudi'
p1=sns.relplot(x='location',y='no2',data=df)
# Out:
# <ipython-input-12-31cf3f177aa3>:5: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("/content/data.csv", encoding='latin1')

# %%
p1=sns.relplot(x='location',y='no2',data=df,hue="state",style="stn_code")
